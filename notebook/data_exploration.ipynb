# %%
import pandas as pd

# %%
df = pd.read_csv("../data/results.csv")

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.isnull().sum()
# Out:
# date           0
# home_team      0
# away_team      0
# home_score    72
# away_score    72
# tournament     0
# city           0
# country        0
# neutral        0
# dtype: int64

# %%
df = df.dropna(subset= ["home_score","away_score"])

# %%
df.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["year"] = df["date"].dt.year

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'year'],
#       dtype='str')

# %%
df["home_score"] = df["home_score"].astype(int)
df["away_score"] = df["away_score"].astype(int)

# %%
def get_result(row):
    if row["home_score"] > row["away_score"]:
        return "home_win"
    elif row["home_score"] < row["away_score"]:
        return "away_win"
    return "draw"

df["result"] = df.apply(get_result, axis=1)

# %%
df.head()
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1873-03-08   England  Scotland           4           2   Friendly   London
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3 1875-03-06   England  Scotland           2           2   Friendly   London
# 4 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year    result
# 0  Scotland    False  1872      draw
# 1   England    False  1873  home_win
# 2  Scotland    False  1874  home_win
# 3   England    False  1875      draw
# 4  Scotland    False  1876  home_win

# %%
print(df["result"].value_counts())
# Out:
# result
# home_win    24149
# away_win    13928
# draw        11204
# Name: count, dtype: int64

# %%
df.to_csv("../data/cleaned_results.csv",index=False)

# %%
df.tail()
# Out:
#             date      home_team away_team  home_score  away_score tournament  \
# 49276 2026-05-31         Poland   Ukraine           0           2   Friendly
# 49277 2026-05-31      Singapore  Mongolia           4           0   Friendly
# 49278 2026-05-31    Switzerland    Jordan           4           1   Friendly
# 49279 2026-05-31  United States   Senegal           3           2   Friendly
# 49280 2026-05-31          Japan   Iceland           1           0   Friendly
#
#              city        country  neutral  year    result
# 49276     Wrocław         Poland    False  2026  away_win
# 49277   Singapore      Singapore    False  2026  home_win
# 49278  St. Gallen    Switzerland    False  2026  home_win
# 49279   Charlotte  United States    False  2026  home_win
# 49280       Tokyo          Japan    False  2026  home_win

# %%
df.shape
# Out:
# (49281, 11)

# %%
df = pd.read_csv("../data/cleaned_results.csv")

# %%
df.shape
# Out:
# (49281, 11)

# %%
df["result"].value_counts()
# Out:
# result
# home_win    24149
# away_win    13928
# draw        11204
# Name: count, dtype: int64

# %%
df["year"].min()
# Out:
# np.int64(1872)

# %%
df["year"].max()
# Out:
# np.int64(2026)

# %%
len(set(df["home_team"]).union(set(df["away_team"])))
# Out:
# 336
